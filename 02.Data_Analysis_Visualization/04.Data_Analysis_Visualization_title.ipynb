# %% [markdown]
# ## 데이터 추출

# %%
import pandas as pd

# 파일 읽기
month_2017 = pd.read_excel('./data/2017_month.xlsx')
month_2018 = pd.read_excel('./data/2018_month.xlsx')
month_2019 = pd.read_excel('./data/2019_month.xlsx')
month_2020 = pd.read_excel('./data/2020_month.xlsx')
month_2021 = pd.read_excel('./data/2021_month.xlsx')

# %%
# 2017~2020 가을(9, 10, 11월) 데이터 추출
Fall = pd.DataFrame()
for data in [month_2017, month_2018, month_2019, month_2020]:
    Fall = pd.concat([Fall, data[data['월'].isin([9, 10, 11])]], ignore_index=True)
Fall
# Out:
#         년도   월   순위                            타이틀                   가수    장르
# 0     2017   9    1  시차 (We Are) (Feat. 로꼬 & GRAY)                  우원재  랩/힙합
# 1     2017   9    2                             좋니                  윤종신   발라드
# 2     2017   9    3                            가시나                   선미    댄스
# 3     2017   9    4                          가을 아침             아이유 (IU)   발라드
# 4     2017   9    5          비도 오고 그래서 (Feat. 신용재)          헤이즈 (Heize)  랩/힙합
# ...    ...  ..  ...                            ...                  ...   ...
# 1195  2020  11   96                            행복해                  송하예   발라드
# 1196  2020  11   97                    시든 꽃에 물을 주듯           HYNN (박혜원)   발라드
# 1197  2020  11   98         하루도 그대를 사랑하지 않은 적이 없었다                  임창정   발라드
# 1198  2020  11   99   사랑에 연습이 있었다면 (Prod. by 2soo)                  임재현   발라드
# 1199  2020  11  100                 사랑이 식었다고 말해도 돼  먼데이 키즈 (Monday Kiz)   발라드
#
# [1200 rows x 6 columns]

# %%
# 연도별 가을(9~11월) 데이터 추출
Fall_2017 = Fall[Fall['년도']==2017]
Fall_2018 = Fall[Fall['년도']==2018]
Fall_2019 = Fall[Fall['년도']==2019]
Fall_2020 = Fall[Fall['년도']==2020]

# %% [markdown]
# ## 제목 길이 분석

# %%
import matplotlib.pyplot as plt
# 한글 표시
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

# 색상 지정
colors = ['indianred', 'coral', 'khaki', 'lightgreen', 'lightblue', 'steelblue', 'plum', 'lightgrey', 'darkseagreen', 'mediumaquamarine', 'lightpink']

# %% [markdown]
# ### 가을

# %%
# 2017년
title_2017 = pd.DataFrame()
title = Fall_2017['타이틀']

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2017 = pd.concat([title_2017, Fall_2017[i:i+1]], ignore_index=True)
title_2017
# Out:
#      년도   월  순위                타이틀           가수      장르
# 0  2017   9  14    잠 못 드는 밤 비는 내리고     아이유 (IU)     발라드
# 1  2017   9  38       첫눈처럼 너에게 가겠다  에일리 (AILEE)     OST
# 2  2017   9  59      너와 함께한 시간 속에서  헤이즈 (Heize)    랩/힙합
# 3  2017   9  92  이 소설의 끝을 다시 써보려 해          한동근     발라드
# 4  2017  10  18    잠 못 드는 밤 비는 내리고     아이유 (IU)     발라드
# 5  2017  10  45       첫눈처럼 너에게 가겠다  에일리 (AILEE)     OST
# 6  2017  11   5      그때의 나, 그때의 우리        어반자카파  R&B/소울
# 7  2017  11  41       첫눈처럼 너에게 가겠다  에일리 (AILEE)     OST
# 8  2017  11  43    잠 못 드는 밤 비는 내리고     아이유 (IU)     발라드

# %%
# 중복 제거
title_2017.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
title_2017
# Out:
#      년도   월  순위                타이틀           가수      장르
# 0  2017   9  14    잠 못 드는 밤 비는 내리고     아이유 (IU)     발라드
# 1  2017   9  38       첫눈처럼 너에게 가겠다  에일리 (AILEE)     OST
# 2  2017   9  59      너와 함께한 시간 속에서  헤이즈 (Heize)    랩/힙합
# 3  2017   9  92  이 소설의 끝을 다시 써보려 해          한동근     발라드
# 4  2017  11   5      그때의 나, 그때의 우리        어반자카파  R&B/소울

# %%
# 2018
title_2018 = pd.DataFrame()
title = Fall_2018['타이틀'].reset_index(drop=True)

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2018 = pd.concat([title_2018, Fall_2018[i:i+1]], ignore_index=True)
           
# 중복 제거
title_2018.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
title_2018
# Out:
#      년도  월  순위                     타이틀           가수   장르
# 0  2018  9  18  하루도 그대를 사랑하지 않은 적이 없었다          임창정  발라드
# 1  2018  9  66            첫눈처럼 너에게 가겠다  에일리 (AILEE)  OST

# %%
# 2019년
title_2019 = pd.DataFrame()
title = Fall_2019['타이틀'].reset_index(drop=True)

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2019 = pd.concat([title_2019, Fall_2019[i:i+1]], ignore_index=True)
           
# 중복 제거
title_2019.drop_duplicates(['타이틀'],inplace=True, ignore_index=True)
title_2019
# Out:
#      년도   월  순위                        타이틀                            가수  \
# 0  2019   9   2   흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야                           장범준
# 1  2019   9   6          기억해줘요 내 모든 날과 그때를                    거미 (Gummy)
# 2  2019   9  22  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지                     AKMU (악뮤)
# 3  2019   9  23             사랑이 식었다고 말해도 돼           먼데이 키즈 (Monday Kiz)
# 4  2019   9  37           너에게 못했던 내 마지막 말은                           다비치
# 5  2019   9  38               내 맘을 볼 수 있나요                   헤이즈 (Heize)
# 6  2019   9  58               주저하는 연인들을 위해                           잔나비
# 7  2019  10  38               그대의 밤, 나의 아침  브라운 아이드 소울 (Brown Eyed Soul)
# 8  2019  11   2          늦은 밤 너의 집 앞 골목길에서                            노을
# 9  2019  11  72            영화 속에 나오는 주인공처럼                    펀치 (Punch)
#
#        장르
# 0     OST
# 1     OST
# 2     발라드
# 3     발라드
# 4     발라드
# 5     OST
# 6      인디
# 7  R&B/소울
# 8     발라드
# 9     OST

# %%
# 2020년
title_2020 = pd.DataFrame()
title = Fall_2020['타이틀'].reset_index(drop=True)

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2020 = pd.concat([title_2020, Fall_2020[i:i+1]], ignore_index=True)

# 중복 제거
title_2020.drop_duplicates(['타이틀'],inplace=True, ignore_index=True)
title_2020
# Out:
#       년도   월  순위                        타이틀                   가수   장르
# 0   2020   9  23   흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야                  장범준  OST
# 1   2020   9  34               사랑하게 될 줄 알았어                  전미도  OST
# 2   2020   9  37           거짓말이라도 해서 널 보고싶어                  백지영  발라드
# 3   2020   9  42          늦은 밤 너의 집 앞 골목길에서                   노을  발라드
# 4   2020   9  45  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지            AKMU (악뮤)  발라드
# 5   2020   9  55        사랑은 지날수록 더욱 선명하게 남아                  전상근  발라드
# 6   2020   9  64            좋은 사람 있으면 소개시켜줘             조이 (JOY)  OST
# 7   2020   9  70               아직 너의 시간에 살아                  이수현  OST
# 8   2020   9  71              어느 60대 노부부이야기                  임영웅  트로트
# 9   2020   9  78               주저하는 연인들을 위해                  잔나비   인디
# 10  2020   9  83               너에게 난, 나에게 넌              미도와 파라솔  OST
# 11  2020   9  84             사랑이 식었다고 말해도 돼  먼데이 키즈 (Monday Kiz)  발라드
# ...

# %%
# 데이터프레임 합치기
titles = pd.concat([title_2017, title_2018, title_2019, title_2020], ignore_index=True)
titles
# Out:
#       년도   월  순위                        타이틀                            가수  \
# 0   2017   9  14            잠 못 드는 밤 비는 내리고                      아이유 (IU)
# 1   2017   9  38               첫눈처럼 너에게 가겠다                   에일리 (AILEE)
# 2   2017   9  59              너와 함께한 시간 속에서                   헤이즈 (Heize)
# 3   2017   9  92          이 소설의 끝을 다시 써보려 해                           한동근
# 4   2017  11   5              그때의 나, 그때의 우리                         어반자카파
# 5   2018   9  18     하루도 그대를 사랑하지 않은 적이 없었다                           임창정
# 6   2018   9  66               첫눈처럼 너에게 가겠다                   에일리 (AILEE)
# 7   2019   9   2   흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야                           장범준
# 8   2019   9   6          기억해줘요 내 모든 날과 그때를                    거미 (Gummy)
# 9   2019   9  22  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지                     AKMU (악뮤)
# 10  2019   9  23             사랑이 식었다고 말해도 돼           먼데이 키즈 (Monday Kiz)
# 11  2019   9  37           너에게 못했던 내 마지막 말은                           다비치
# ...

# %%
# 연도별 차트인 횟수 계산 후 데이터프레임 생성
title_length = pd.DataFrame(titles.value_counts('년도'), columns=['횟수'], index=[2017,2018,2019,2020])
title_length
# Out:
#       횟수
# 2017   5
# 2018   2
# 2019  10
# 2020  15

# %%
# 시각화
title_length.plot(kind='bar')
plt.title('제목 길이가 12자 이상인 노래의 가을 차트인 횟수')
plt.xlabel('연도')
plt.ylabel('차트인 횟수')
# Out:
# Text(0, 0.5, '차트인 횟수')

# %% [markdown]
# ### 전체

# %%
# 2017년
title_2017 = pd.DataFrame()
title = month_2017['타이틀']

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2017 = pd.concat([title_2017, month_2017[i:i+1]], ignore_index=True)
            
# 중복 제거
title_2017.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
title_2017
# Out:
#      년도   월  순위                타이틀           가수      장르
# 0  2017   1   1       첫눈처럼 너에게 가겠다  에일리 (AILEE)     OST
# 1  2017   1  23  이 소설의 끝을 다시 써보려 해          한동근     발라드
# 2  2017   8  86      너와 함께한 시간 속에서  헤이즈 (Heize)    랩/힙합
# 3  2017   9  14    잠 못 드는 밤 비는 내리고     아이유 (IU)     발라드
# 4  2017  11   5      그때의 나, 그때의 우리        어반자카파  R&B/소울

# %%
# 2018년
title_2018 = pd.DataFrame()
title = month_2018['타이틀']

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2018 = pd.concat([title_2018, month_2018[i:i+1]], ignore_index=True)
            
# 중복 제거
title_2018.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
title_2018
# Out:
#      년도   월  순위                     타이틀           가수      장르
# 0  2018   1  22           그때의 나, 그때의 우리        어반자카파  R&B/소울
# 1  2018   1  38           다른사람을 사랑하고 있어    수지 (SUZY)     발라드
# 2  2018   1  40            첫눈처럼 너에게 가겠다  에일리 (AILEE)     OST
# 3  2018   1  91         잠 못 드는 밤 비는 내리고     아이유 (IU)     발라드
# 4  2018   3  91            바람이 불었으면 좋겠어         길구봉구  R&B/소울
# 5  2018   9  18  하루도 그대를 사랑하지 않은 적이 없었다          임창정     발라드
# 6  2018  12  77          너도 그냥 날 놓아주면 돼           윤건     발라드

# %%
# 2019년
title_2019 = pd.DataFrame()
title = month_2019['타이틀']

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2019 = pd.concat([title_2019, month_2019[i:i+1]], ignore_index=True)
            
# 중복 제거
title_2019.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
title_2019
# Out:
#       년도   월  순위                                                타이틀  \
# 0   2019   1  15                                     너도 그냥 날 놓아주면 돼
# 1   2019   1  25                             하루도 그대를 사랑하지 않은 적이 없었다
# 2   2019   1  35                                    이 노래가 클럽에서 나온다면
# 3   2019   1  56                                       첫눈처럼 너에게 가겠다
# 4   2019   3  10                                       주저하는 연인들을 위해
# 5   2019   3  12                                그건 아마 우리의 잘못은 아닐 거야
# 6   2019   4  29                             뜨거운 여름밤은 가고 남은 건 볼품없지만
# 7   2019   4  77  사랑하긴 했었나요 스쳐가는 인연이었나요 짧지않은 우리 함께했던 시간들이 자꾸 내 마...
# 8   2019   5  11                                   너에게 못했던 내 마지막 말은
# 9   2019   5  76                                     사랑이 식었다고 말해도 돼
# 10  2019   8   1                                  기억해줘요 내 모든 날과 그때를
# 11  2019   8  16                                       내 맘을 볼 수 있나요
# 12  2019   9   2                           흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# ...

# %%
# 2020년
title_2020 = pd.DataFrame()
title = month_2020['타이틀']

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2020 = pd.concat([title_2020, month_2020[i:i+1]], ignore_index=True)
            
# 중복 제거
title_2020.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
title_2020
# Out:
#       년도   월   순위                        타이틀                   가수   장르
# 0   2020   1    5          늦은 밤 너의 집 앞 골목길에서                   노을  발라드
# 1   2020   1    9   흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야                  장범준  OST
# 2   2020   1   11  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지            AKMU (악뮤)  발라드
# 3   2020   1   13   다시는 사랑하지 않고, 이별에 아파하기 싫어                  백지영  발라드
# 4   2020   1   25           헤어진 우리가 지켜야 할 것들            김나영 & 양다일  발라드
# 5   2020   1   32               십이월 이십오일의 고백                  정승환  발라드
# 6   2020   1   38          기억해줘요 내 모든 날과 그때를           거미 (Gummy)  OST
# 7   2020   1   45             사랑이 식었다고 말해도 돼  먼데이 키즈 (Monday Kiz)  발라드
# 8   2020   1   71           너에게 못했던 내 마지막 말은                  다비치  발라드
# 9   2020   1   73               주저하는 연인들을 위해                  잔나비   인디
# 10  2020   2   13              잘 지내고 있는지 궁금해                V.O.S  발라드
# 11  2020   2   74               우는 법을 잊어버렸나요            이해리 (다비치)  발라드
# ...

# %%
# 2021년
title_2021 = pd.DataFrame()
title = month_2021['타이틀']

# 부제목, 영어 제목 제외 길이가 12자 이상인 곡 추출
for i in range(len(title)):
    if (len(title[i].split(' (')[0])>=12) and (title[i].upper() == title[i].lower()):
            title_2021 = pd.concat([title_2021, month_2021[i:i+1]], ignore_index=True)
            
# 중복 제거
title_2021.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
title_2021
# Out:
#       년도  월  순위                        타이틀                  가수   장르
# 0   2021  1   1              우린 어쩌다 헤어진 걸까                  허각  발라드
# 1   2021  1  15               힘든 건 사랑이 아니다                 임창정  발라드
# 2   2021  1  25   흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야                 장범준  OST
# 3   2021  1  39             그날에 나는 맘이 편했을까                 이예준  발라드
# 4   2021  1  43          늦은 밤 너의 집 앞 골목길에서                  노을  발라드
# 5   2021  1  49  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지           AKMU (악뮤)  발라드
# 6   2021  1  53          밝게 빛나는 별이 되어 비춰줄게                 송이한   인디
# 7   2021  1  86               주저하는 연인들을 위해                 잔나비   인디
# 8   2021  1  92               첫눈처럼 너에게 가겠다         에일리 (AILEE)  OST
# 9   2021  1  96           거짓말이라도 해서 널 보고싶어                 백지영  발라드
# 10  2021  1  97               사랑하게 될 줄 알았어                 전미도  OST
# 11  2021  2  38               오늘도 난 봄을 기다려         케이시 (Kassy)  발라드
# 12  2021  3  39               별빛 같은 나의 사랑아                 임영웅  트로트
# ...

# %%
# 데이터프레임 합치기
titles = pd.concat([title_2017, title_2018, title_2019, title_2020, title_2021], ignore_index=True)
titles.drop_duplicates(['타이틀'], inplace=True, ignore_index=True)
titles
# Out:
#       년도   월   순위                                                타이틀  \
# 0   2017   1    1                                       첫눈처럼 너에게 가겠다
# 1   2017   1   23                                  이 소설의 끝을 다시 써보려 해
# 2   2017   8   86                                      너와 함께한 시간 속에서
# 3   2017   9   14                                    잠 못 드는 밤 비는 내리고
# 4   2017  11    5                                      그때의 나, 그때의 우리
# 5   2018   1   38                                      다른사람을 사랑하고 있어
# 6   2018   3   91                                       바람이 불었으면 좋겠어
# 7   2018   9   18                             하루도 그대를 사랑하지 않은 적이 없었다
# 8   2018  12   77                                     너도 그냥 날 놓아주면 돼
# 9   2019   1   35                                    이 노래가 클럽에서 나온다면
# 10  2019   3   10                                       주저하는 연인들을 위해
# 11  2019   3   12                                그건 아마 우리의 잘못은 아닐 거야
# 12  2019   4   29                             뜨거운 여름밤은 가고 남은 건 볼품없지만
# ...

# %%
# 연도별 차트인 횟수 계산 후 데이터프레임 생성
title_length = pd.DataFrame(titles.value_counts('년도'), columns=['횟수'], index=[2017,2018,2019,2020, 2021])
title_length
# Out:
#       횟수
# 2017   5
# 2018   4
# 2019  18
# 2020  16
# 2021  10

# %%
# 2021
title_length2021 = pd.DataFrame(titles[titles['년도']==2021].value_counts('월'), columns=['횟수'])
title_length2021.sort_index(inplace=True)
title_length2021.index=[1,2,3,4,6,7]
title_length2021.loc[5]=0
title_length2021.loc[8]=0
title_length2021.sort_index(inplace=True)
title_length2021
# Out:
#    횟수
# 1   2
# 2   1
# 3   2
# 4   1
# 5   0
# 6   3
# 7   1
# 8   0

# %%
plt.figure(figsize=(8,6))
#plt.suptitle('제목 길이가 12자 이상인 노래의 차트인 횟수',fontsize=15)

# 2017~2021 연도별
#plt.subplot(1,2,1)
plt.bar(title_length.index, title_length['횟수'])
plt.title('연도별 제목 길이가 12자 이상인 노래의 차트인 횟수')
plt.xlabel('연도')
plt.ylabel('횟수')
plt.ylim(0,19)

# # 2021년 월별
# plt.subplot(1,2,2)
# plt.bar(title_length2021.index, title_length2021['횟수'])
# plt.title('2021년 1~8월 월별')
# plt.xlabel('월')
# plt.ylabel('횟수')
# plt.ylim(0,19)
# Out:
# (0.0, 19.0)
